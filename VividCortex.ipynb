# %%
import mingl
reload(mingl)
import os

m = mingl.Mingl(os.getenv("TWITTER_CONSUMER_KEY"), os.getenv("TWITTER_CONSUMER_SECRET"))

# %%
dev_ops = ['RealGeneKim', 'lusis', 'mindweather', 'solarce', 'nathenharvey']
vc_customers = ["NinjaBunny_","AaronBBrown777","itaykahana","tiopaul","MartinLoy","LaineVCampbell","duanegran","jbarciauskas",
    "snoogindoogin","chuckhagenbuch","yournameistoby","blalor","GiantEvolving","cvshumake","insyteful","samkottler","timgoodaire",
    "DynData","egon1024","MathYourLife","j_manero","obfuscurity","bigg33k","alexsergeyev","akachler","mrtazz","ickymettle","lozzd",
    "allspaw","Ryan_Frantz","mikearpaia","d87tech","techwolf359","wcgallego","jimbartus","dominis","pk11","herczog","balagez",
    "privateblue","mthology","BenRegenspan","MsLaurenRae","emittelhammer","oacgnol","highmountain","isamlambert","dbussink",
    "alindeman","saxenaan","mezis_fr","zvikico","aryanet","interskh","thilorusche","lmcdowell ","dgenzale","djuntgen","productiondba",
    "maximefouilleul","TeeKraken","olafvanzandwijk","JoshuaPrunier","gudlyf","ShayYannay","j8erg","rkuris","ShlomiNoach","mazorE",
    "web007","dbaldwin","tobi","phlipper","skingry","johnduff","fbogsany  ","honkfestival","TomCallway","RonaldBradford","banpei",
    "bboskoff","John_Cesario","SquareNerd","maniksurtani","MichaelLossos","jeeyoungk","3ameam","abhay","sfermigier","djapg",
    "JeromeThibaud","jsjacob","krudnicki","ValerieNC","huntersatter"]

# before running these turn off limits
#related_groups = ["PerconaLive","Percona","velocityconf","newrelic","newrelicstatus","webyog","WebyogJobs","skysql","OracleDatabase","MySQL","xaprb","datacenter","AppDynamics"]

# %%
friends = m.get_friends(vc_customers)

# %%
friends = m.get_followers(test)

# %%
friends = m.hydrate_users(friends)

# %%
for k,v in friends.iteritems():
    print k
    for u in v:
        print "\t", u.screen_name, u.id ,"\n\t\t",u["name"],"\n\t\t",u["description"],"\n\n"
   #     print "\t", u.screen_name
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-bd8aac0dfca3> in <module>()
#       2     print k
#       3     for u in v:
# ----> 4         print "\t", u.screen_name, u.id ,"\n\t\t",u["name"],"\n\t\t",u["description"],"\n\n"
#       5    #     print "\t", u.screen_name
#
# /Users/jnbrymn/Personal/Programming/MinglBot/code/mingl.pyc in __getitem__(self, key)
#      49
#      50     def __getitem__(self,key):
# ---> 51         return self._properties[key]
#      52
#      53     def __contains__(self,key):
#
# KeyError: 'name'
# 24
# 	github 13334762
# 		GitHub
# 		Social coding.
#
#
# 	allspaw 13378422
# 		John Allspaw
# 		SVP Tech Operations, Etsy.
# Dad. Author. Guitarist.
# Systems Safety student.
# Terrible bio-writer.
#
#
# 23
# 	xaprb 28325059
# 		Baron Schwartz
# 		Founder and CEO @VividCortex. Author of High Performance MySQL. CrossFit, engineering, deep thoughts.
#
#
# 22
# 	devops_borat 167499429
# 		DevOps Borat
# 		Cultural Learnings of DevOps for Make Benefit Glorious Teams of Devs and Ops.
#
#
# 19
# 	neiltyson 19725644
# 		Neil deGrasse Tyson
# 		Astrophysicist.  Author: Space Chronicles & Inexplicable Universe [Video]; Host: @StarTalkRadio & @COSMOSonTV
#
#
# 18
# 	markimbriaco 9887162
# 		Mark Imbriaco
# 		VP TechOps @ DigitalOcean. Previously: GitHub, LivingSocial, Heroku, and 37signals. Dad to 4 fantastic kids. #opslife
#
#
# 16
# 	codinghorror 5637652
# 		Jeff Atwood
# 		Indoor enthusiast. Co-founder of http://t.co/JbStnko3pv and http://t.co/kaSwrMgE57. Disclaimer: I have no idea what I'm talking about.
#
#
# 	coda 637533
# 		Coda Hale
# 		The dog who belonged to himself.
#
#
# 15
# 	dropbox 14749606
# 		Dropbox
# 		Your stuff, anywhere. For account support, head over to @Dropbox_Support.
#
#
# 	obfuscurity 66432490
# 		Jason Dixon
# 		Customer Success @ Wavefront. Previously: Dyn, GitHub, Heroku and OmniTI/Circonus.
#
#
# 	crucially 2334251
# 		Artur Bergman
# 		CEO of Fastly, hates slow things, temporarily not nomadic.
#
#
# 	climagic 91333167
# 		Command Line Magic
# 		Cool Unix/Linux Command Line tricks you can use in 140 characters or less.
#
#
# 	mrtazz 810781
# 		Daniel Schauenberg
# 		Infrastructure Toolsmith at Etsy.
# A Cheap Trick and a Cheesy One-Liner.
# You can't be a non-conformist, if you don't drink coffee.
#
#
# 14
# 	oatmeal 4519121
# 		Matthew Inman
# 		I make comics.
#
#
# 	shit_hn_says 752430234
# 		Shit HN Says
# 		reality? what's that? does it use node.js?
#
#
# 13
# 	postwait 9580822
# 		Theo Schlossnagle
# 		CEO of Circonus.
# Founder at Message Systems, Fontdeck, OmniTI.
# Dad.
#
#
# 	codeascraft 112601087
# 		Etsy Engineering
#
#
#
# 	spolsky 15948437
# 		Joel Spolsky
# 		Co-founder of Fog Creek Software (Trello, FogBugz, Kiln) and Stack Exchange (Stack Overflow etc). Member of NYC gay startup mafia.
#
#
# 	igrigorik 9980812
# 		Ilya Grigorik
# 		Web performance engineer & developer advocate @ Google. I make things fast.
#
#
# 	vividcortex 760627034
# 		VividCortex
# 		MySQL database performance management in the cloud. Sign up for a free trial today!
#
#
# 	laraswanson 14146300
# 		Lara Swanson
# 		Engineering Manager, Performance @Etsy
#
#
# 	percona 35373186
# 		Percona
# 		Percona's MySQL consulting, support, training, Remote DBA, server development services & open source MySQL software help people achieve breakthrough results.
#
#
# 	aphyr 49820803
# 		Eigenstud
# 		Mom of Finland. 'Of interest only to third-rate academics a few papers short of a tenure package.'  -Jim Starkey. 'Too NSFW for academia' -@lindsey.
#
#
# 	timoreilly 2384071
# 		Tim O'Reilly
# 		Founder and CEO, O'Reilly Media. Watching the alpha geeks, sharing their stories, helping the future unfold.
#
#
# 	conanobrien 115485051
# 		Conan O'Brien
# 		The voice of the people. Sorry, people.
#
#
# 12
# 	fredwilson 1000591
# 		Fred Wilson
# 		I am a VC
#
#
# 	jordansissel 15782607
# 		@jordansissel
# 		hacker. Free hugs given upon request.
#
#
# 	twittereng 6844292
# 		Twitter Engineering
# 		The official account for Twitter Engineering.
#
#
# 	defunkt 713263
# 		Chris Wanstrath
# 		GitHub Co-Founder & CEO
#
#
# 	elonmusk 44196397
# 		Elon Musk
# 		Tesla, SpaceX, SolarCity & PayPal
#
#
# 	marscuriosity 15473958
# 		Curiosity Rover
# 		NASA's latest mission to explore the surface of  Mars. Roving the Red Planet since Aug. 5, 2012 (PDT) (Aug 6 UTC).
#
#
# 	mrembetsy 20456848
# 		Michael Rembetsy
# 		nerd @etsy
#
#
# 	beerops 260044118
# 		(╯°□°）╯︵ sdoɹəəq
# 		Sparkly devops princess @GCSports, hot saucerer, drinker of good beer, homebrewer, pythonista, climber, violinist, aspiring cellist, queer, gamer, metalhead.
#
#
# 	jamesgolick 12027042
# 		James Golick
#
#
#
# 	paulg 183749519
# 		Paul Graham
#
#
#
# 11
# 	petecheslock 264481774
# 		Pete Cheslock
# 		ᕕ( ᐛ )ᕗ
#
# On my way to secure ur cloud.
#
# I also do @BosOps & @ShipShowPodcast.
#
# Food, Cycling, Scotch.
# PGP: http://t.co/kkczEQraal
#
#
# 	chaddickerson 632343
# 		Chad Dickerson
# 		CEO, Etsy
#
#
# 	jeresig 752673
# 		John Resig
# 		Creator of @jquery, JavaScript programmer, author, Japanese woodblock nerd (http://t.co/vc69XXB4fq), work at @khanacademy.
#
#
# 	avibryant 13192
# 		Avi Bryant
# 		I like working for small companies from small islands. Currently @stripe.
#
#
# 	werner 113963
# 		Werner Vogels
# 		CTO @ Amazon
#
#
# 	twitter 783214
# 		Twitter
# 		Your official source for news, updates and tips from Twitter, Inc.
#
#
# 	lozzd 8627682
# 		Laurie Denness
# 		Operating operations at @Etsy. I like graphs, Hadoop clusters, monitoring and sarcasm
#
#
# 	shitmydadsays 62581962
# 		Justin
# 		Author of Shit My Dad Says and, coming May 15th, my new book I Suck At Girls. My dad's in it, don't worry. This account is where I publish the shit that he says
#
#
# 	newrelic 15527007
# 		New Relic
# 		Software Analytics for Ruby, PHP, Python, Java, .NET, Node, iOS and Android Apps. We collect 250 billion+ metrics daily.
#
#
# 	kyleredinger 38686230
# 		Kyle Redinger
# 		serial do-er º startups º CrossFitter º Darden MBA º epicurean
#
#
# 	benjammingh 42007556
# 		Ben Hughes
# 		Absent father, disappointed husband, serial non-achiever. Aspiring script kiddie. Lack of Thought Leader. Webmaster. Guy Gamer. Geek Girl. Cat Lady. GPG 0x6
#
#
# 10
# 	plunkett 1765131
# 		thomas plunkett
#
#
#
# 	kellan 47
# 		kellan
# 		CTO at Etsy. Technical solutions for social problems. #47 (Anwen's dad)
#
#
# 	rasmus 928961
# 		Rasmus Lerdorf
# 		Breaking the Web
#
#
# 	hipsterhacker 261546340
# 		Hipster Hacker
# 		My code is poetry, meanwhile yours is oh-noetry.
#
#
# 	indec 17840694
# 		Ian Malpass
# 		Software engineer at Etsy. Dad in Minnesota.
#
#
# 	garybernhardt 809685
# 		Gary Bernhardt
# 		not a rubyist, not a husband, not a father, not a christian, not a dog, not a horse
#
#
# 	sophaskins 10201312
# 		Sophie Haskins
# 		is made of *so many* bones
#
#
# 	billgates 50393960
# 		Bill Gates
# 		Sharing things I'm learning through my foundation work and other interests...
#
#
# 	google 20536157
# 		A Googler
# 		News and updates from Google
#
#
# 	kellabyte 47494539
# 		Kelly Sommers
# 		DataStax MVP for Apache Cassandra and Windows Azure MVP, Backend brat, big data, distributed diva and mobile dev maven. Relentless learner. I void warranties.
#
#
# 	ryan_frantz 354998770
# 		Ryan Frantz
# 		Proud husband and father.  Loves eat, drink, and tech.  Senior Operations Engineer @Etsy.
#
#
# 	avleen 15696107
# 		avleen
# 		Engineering up some awesomeness at Etsy
#
#
# 	bitfield 14375294
# 		John Arundel
# 		Helps with sysadmin, devops, Puppet stuff. Writes the odd book.
#
#
# 	hmason 765548
# 		Hilary Mason
# 		Founder at @FastForwardLabs. Data Scientist in Residence at @accel. I ♥ data and cheeseburgers.
#
#
# 	jonlives 13093162
# 		Jon Cowie
# 		Senior Operations Engineer @ Etsy, Author of Customizing Chef
#
#
# 	None 10403812

# %% [markdown]
# #Trash Below Here

# %%
class Asdf:
    def  __init__(self):
        self.bacon = 5
    
    def asdf():
        pass
    bacon = 4
    def qwer(self):
        print self.bacon
        print Asdf.bacon

# %%
a = Asdf()
a.qwer()
# Out:
# 5
# 4
